# %% [markdown]
# # Python Operators

# %%
Image('2.png')

# %% [markdown]
# ## 1. Arithmetic Operators

# %%
Image('3.png')

# %% [markdown]
# #### The most common arithmetic Operators are
#                                                 + (Addition)
#                                                 – (Subtraction)
#                                                 * (Multiplication)
#                                                 / (Division)
#                                                 % (Modulus)

# %% [markdown]
# The order of priority in python for arithmetic operator is
#
# 1.Exponential
# 2.Division
# 3.Multipliaction
# 4.Addition
# 5.Subtraction

# %% [markdown]
# #### 1. + Addition Operator

# %%
# Adding two Variables which has a int values
A = 30
B = 20
C = A+B
print(C)
print(type(C))
# Out:
# 50
# <class 'int'>

# %%
# Adding two Variables which has a int and float values
a = 4 + 3.2
print(a)
print(type(a))
# Out:
# 7.2
# <class 'float'>

# %% [markdown]
# #### Addition with string variable

# %%
# Adding two strings
a = 'Technical' + 'Seek'
print(a)
print(type(a))
# Out:
# TechnicalSeek
# <class 'str'>

# %%
# Adding the "Strings" + '4' 
a = 'Technical' + 'Seek' +'4' # here 4 is string
a
# Out:
# 'TechnicalSeek4'

# %%
# Adding the "Strings" + 4
a = 'Technical' + 'Seek' + 4 # here 4 is integer
a

# we cannot add a string with numbers and so it will throw an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-8f0059d112d9> in <module>
#       1 # Adding the "Strings" + 4
# ----> 2 a = 'Technical' + 'Seek' + 4 # here 4 is string
#       3 a
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# #### 2. - subtraction Operator

# %%
# subtracting two Variables
A = 30
B = 20
C = A-B
print(C)
print(type(C))
# Out:
# 10
# <class 'int'>

# %%
# subtracting the multiple values which is int
a = 4 - 3 - 4
print(a)
print(type(a))
# Out:
# -3
# <class 'int'>

# %%
# subtracting the multiple values with int and float
a = 14 - 2.6 - 4

print(a)
print(type(a))
# Out:
# 7.4
# <class 'float'>

# %%
# subtract 2 string
a = "Aakash"
b = "Raj"
c = a-b
print(c)

# note: we cannot subtract 2 strings
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-828ec4d09d61> in <module>
#       2 a = "Aakash"
#       3 b = "Raj"
# ----> 4 c = a-b
#       5 print(c)
#       6
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# #### 3. *    - Multiplication Operator

# %%
# Multiply two Variables both the values are integer
A = 30
B = 20
C = A*B
print(C)
print(type(C))
# Out:
# 600
# <class 'int'>

# %%
# Multiply two Variables  the values are integer and float
A = 30
B = 20.5
C = A*B
print(C)
print(type(C))
# Out:
# 615.0
# <class 'float'>

# %%
# Multiply string with number , data gets repeated
a = 'abc' * 3
a
# Out:
# 'abcabcabc'

# %%
# Multiplication of 2 string is not possible

a = "Aakash"
b = "Raj"
c= a*b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-54357db3ad86> in <module>
#       3 a = "Aakash"
#       4 b = "Raj"
# ----> 5 c= a*b
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# #### 4. /   - Division Operator

# %%
# Division using 2 variables and both the values are integer
a = 27
b = 2
c = a / b
print(c)
print(type(c))

# note : though both the inputs are int, division output will be always float
# Out:
# 13.5
# <class 'float'>

# %%
# Division using 2 variables and  values are integer and float
a = 27
b = 2.0
c = a / b
print(c)
print(type(c))

# note : though both the inputs are int, division output will be always float
# Out:
# 13.5
# <class 'float'>

# %%
# Division using 2 variables and  values are integer string
a = "Aakash Raj"
b = 2.0
c = a / b
print(c)
print(type(c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-fc3d28528cbc> in <module>
#       2 a = "Aakash Raj"
#       3 b = 2.0
# ----> 4 c = a / b
#       5 print(c)
#       6 print(type(c))
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %% [markdown]
# #### 5. // (Division Operators)

# %%
a = 27
b = 2
c = a // b
c

# Note : returns the quotient with integer as value
# Out:
# 13

# %%
a = 27.5
b = 2
c = a // b
c

# Note : returns the quotient with float value, but still it take the integer value
# Out:
# 13.0

# %% [markdown]
# #### 6. % Modulus

# %%
# Modulus - Find the remainder
A = 30
B = 20
C = A % B
C
# Out:
# 10

# %% [markdown]
#
# #### Special Arithmetic Operators:
#
#                                  //(Division Operators)
#                                  **(Square)

# %%
# Division Operators (//-floored quotient)
A = 30.5
B = 20
C = A // B
C

#Also known as floored quotient and it returns output with integer value(int datatype)
# Out:
# 1.0

# %%
# Square (**-square operator for exponential function)
A = 5
B = 3
C = A ** B
C
# Out:
# 125

# %%
# % Modulus Opeators(%-to find the remainder)

a=30
b=20
c=a%b
print(c)
print(type(c))
# Out:
# 10
# <class 'int'>

# %%
# divmod(x,y) : this operatoe gives the output as quotient/remainder)

x=30
y=20
divmod(30,20)
# Out:
# (1, 10)

# %%
# pow(x,y) (exponetial operator)

x=10
y=10
pow(10,10)
# Out:
# 10000000000

# %% [markdown]
# #### Practice

# %%
## find the Squared output
x = 10
out = x*x
print("squared output :", out)
# Out:
# squared output : 100

# %%
## find the power
x = 10
out = x**x
print("power output :", out)
# Out:
# power output : 10000000000

# %% [markdown]
# ### Run time variable

# %%
nm = input("enter your name")
print("Welcome !!!", nm)
# Out:
# enter your namePeter
# Welcome !!! Peter

# %%
type(nm)
# default data type of nm variable is string
# Out:
# str

# %%
# Get 2 variable in run time and add it
A = input()
B = input()
out = A + B
out
# Out:
# 1
# 2
# '12'

# %%
# inference : the output is not added but concatenated
# reason is, the input variable by default is string and not int

# %% [markdown]
# #### Arithmetic Operators Problem:

# %% [markdown]
#     Step 1: Assign value to A=22 and B=33
#     Step 2: Add value of A and B (22+33=55)
#     Step 3: To this result add A to the output of Step 2 ( 55+22)
#     Step 4: It will print the final result as 77

# %%
A = input()
B = input()
result = A + B

print("Addition of runtime variables are : ", result)

# note :  by default the run time parameter is string datatype.
# instead of addition, concatenation is done because input is string data type
# Out:
# 10
# 20
# Addition of runtime variables are :  1020

# %%
A = int(input())
B = int(input())
result = A + B

print("Addition of runtime variables are : ", result)
# Out:
# 10
# 20
# Addition of runtime variables are :  30

# %%
# pass the input 10, 10.5.
# both the input are int - type casting, one of the input has to be flaot
A = int(input())
B = int(input())
result = A + B

print("Addition of runtime variables are : ", result)
# Out:
# 10
# 10.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-7a9337c9f7ec> in <module>
#       1 A = int(input())
# ----> 2 B = int(input())
#       3 result = A + B
#       4
#       5 print("Addition of runtime variables are : ", result)
#
# ValueError: invalid literal for int() with base 10: '10.4'

# %%
A = int(input())
B = float(input())
result = A + B

print("Addition of runtime variables are : ", result)
# Out:
# 10
# 12.4
# Addition of runtime variables are :  22.4

# %% [markdown]
# ## 2. Relation  Operator - Out will be boolean

# %%
Image('4.png')

# %%
x = 100
y = 12

# %%
# Output: x > y is True
print('x > y  is',x>y)
# Out:
# x > y  is True

# %%
# x < y  is False
print('x < y  is',x<y)
# Out:
# x < y  is False

# %%
#x == y is False
print('x == y is',x==y)
# Out:
# x == y is False

# %%
# Output: x != y is True
print('x != y is',x!=y)
# Out:
# x != y is True

# %%
# x >= y is True
print('x >= y is',x>=y)
# Out:
# x >= y is True

# %%
# Output: x <= y is False
print('x <= y is',x<=y)
# Out:
# x <= y is False

# %% [markdown]
# ## 3. Logical Operators - Output will be in Boolean

# %%
Image('5.png')

# %% [markdown]
# #### 1.And Operator

# %%
Image('6.png')

# %%
x = True
y = False

# Output: x and y is False
print('x and y is',x and y)
# Out:
# x and y is False

# %% [markdown]
# #### 2. OR Operator

# %%
Image('7.png')

# %%
x = True
y = False

# Output: x or y is True
print('x or y is',x or y)
# Out:
# x or y is True

# %% [markdown]
# #### 3. NOT Operator

# %%
Image('8.png')

# %%
x = True
y = False

# Output: not x is False
print('Not x is : ',not x)
# Out:
# Not x is :  False

# %% [markdown]
# ## 4. Bitwise Operators

# %%
Image('9.png')

# %%
a=10 # binary 1010
b=7  # binary 0111
print(a&b)
# Out:
# 2

# %%
a=20 
b=17  
print(a|b)
# Out:
# 21

# %%
a=60 
b=17  
print(a^b)
# Out:
# 45

# %%
a = 20
print(~a)
# Out:
# -21

# %%
a=50
print(a<<1)
# Out:
# 100

# %%
print(a>>1)
# Out:
# 25

# %% [markdown]
# ### 5. Assignment Operation

# %%
Image('10.png')

# %%
# Addition
a=3
b=4

a+=b
#a = a+b # above code is as same as this line

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 7
# b: 4

# %%
# Subtraction
a=3
b=4

a-=b


print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: -1
# b: 4

# %%
# Multiplication
a=3
b=4

a*=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 12
# b: 4

# %%
# Division
a=3
b=4

a/=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 0.75
# b: 4

# %%
a=3
b=4

a%=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 3
# b: 4

# %%
a=3
b=4

a**=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 81
# b: 4

# %%
a=3
b=4

a//=b

print("a: "+str(a))
print("b: "+str(b))
# Out:
# a: 0
# b: 4

# %% [markdown]
# ### Concatenate

# %% [markdown]
# ###### 1.Concatenating and Joining Strings

# %%
'a' + 'b' + 'c'
# Out:
# 'abc'

# %%
'do' * 3
# Out:
# 'dododo'

# %% [markdown]
# ###### 2. Concatenating With .Join()

# %%
strings = ['do', 're', 'mi']
' , '.join(strings)
# Out:
# 'do , re , mi'

# %%
strings = ['do', 're', 'mi']
' # '.join(strings)
# Out:
# 'do # re # mi'

# %% [markdown]
# ###### 2. Multiple ways of printing the statement

# %%
first = 10
second = 20
print ("First number is", first, "and second number is", second)
# Out:
# First number is 10 and second number is 20

# %%
first = 10
second = 20
print ("First number is {}  and second number is {}".format(first,second))
# Out:
# First number is 10.222333  and second number is 20

# %%
first = 10.234556
second = 20.432111

## type cast the float into int while printing
print("first value : %d ,second :  %d \n" %(first,second))
# Out:
# first value : 10 ,second :  20

# %%
first = 10.234556
second = 20.432111

## print the variable as is
print("first value : %f ,second :  %f \n" %(first,second))
# Out:
# first value : 10.234556 ,second :  20.432111

# %%
first = 10.234556
second = 20.432111

## restrict the float to 3 deigits
print("first value : %0.3f ,second :  %0.3f " %(first,second))
# Out:
# first value : 10.235 ,second :  20.432

# %%
# print the code with specific delimiter
print(1, 2, 3, 4, sep=' # ')
# Out:
# 1 # 2 # 3 # 4
